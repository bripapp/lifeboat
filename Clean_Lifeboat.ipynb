# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

# Matplotlib visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# Set default font size
plt.rcParams['font.size'] = 24

# Internal ipython tool for setting figure size
from IPython.core.pylabtools import figsize

# Seaborn for visualization
import seaborn as sns
sns.set(font_scale = 2)

# Splitting data into training and testing
from sklearn.model_selection import train_test_split

# %%
# Read in data into a dataframe
data = pd.read_csv('data/full.csv')

# Display top of dataframe
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1       0.0       3
# 1             2       1.0       1
# 2             3       1.0       3
# 3             4       1.0       1
# 4             5       0.0       3
# 5             6       0.0       3
# 6             7       0.0       1
# 7             8       0.0       3
# 8             9       1.0       3
# 9            10       1.0       2
# 10           11       1.0       3
# 11           12       1.0       1
# 12           13       0.0       3
# 13           14       0.0       3
# 14           15       0.0       3
# 15           16       1.0       2
# 16           17       0.0       3
# 17           18       1.0       2
# 18           19       0.0       3
# 19           20       1.0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# See the column data types and non-missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
data = data.drop(['Age', 'Name', 'Name_wiki', 'Body', 'Lifeboat', 'Cabin', 'Ticket', 'Embarked', 'WikiId', 'Class'], axis='columns')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare  Age_wiki  \
# 0            1       0.0       3    male      1      0   7.2500      22.0
# 1            2       1.0       1  female      1      0  71.2833      35.0
# 2            3       1.0       3  female      0      0   7.9250      26.0
# 3            4       1.0       1  female      1      0  53.1000      35.0
# 4            5       0.0       3    male      0      0   8.0500      35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination
# 0  Qu'Appelle Valley, Saskatchewan, Canada
# 1                   New York, New York, US
# 2                            New York City
# ...

# %%
data_df = data.rename(columns={"Pclass":"Passenger Class", "SibSp":"Siblings", "Parch":"Parent/Child", "Age_wiki":"Age"})
data_df.head()
# Out:
#    PassengerId  Survived  Passenger Class     Sex  Siblings  Parent/Child  \
# 0            1       0.0                3    male         1             0
# 1            2       1.0                1  female         1             0
# 2            3       1.0                3  female         0             0
# 3            4       1.0                1  female         1             0
# 4            5       0.0                3    male         0             0
#
#       Fare   Age                            Hometown      Boarded  \
# 0   7.2500  22.0          Bridgerule, Devon, England  Southampton
# 1  71.2833  35.0              New York, New York, US    Cherbourg
# 2   7.9250  26.0                  Jyväskylä, Finland  Southampton
# 3  53.1000  35.0         Scituate, Massachusetts, US  Southampton
# 4   8.0500  35.0  Birmingham, West Midlands, England  Southampton
#
#                                Destination
# 0  Qu'Appelle Valley, Saskatchewan, Canada
# ...

# %%
data_df.to_csv(r'full_clean.csv', index = False)

# %%
# Function to calculate missing values by column
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(data)

# %%
# Histogram Plot of survivors
figsize(8, 8)
plt.hist(data['Passenger Class'].dropna(), bins = 20, edgecolor = 'black');
plt.xlabel('Class'); 
plt.ylabel('Count'); plt.title('Class Distribution');

# %%
survivor_only = data_df.loc[data_df['Survived'] == 1.0]
survivor_only.head()
# Out:
#    PassengerId  Survived  Passenger Class     Sex  Siblings  Parent/Child  \
# 1            2       1.0                1  female         1             0
# 2            3       1.0                3  female         0             0
# 3            4       1.0                1  female         1             0
# 8            9       1.0                3  female         0             2
# 9           10       1.0                2  female         1             0
#
#       Fare   Age                        Hometown      Boarded  \
# 1  71.2833  35.0          New York, New York, US    Cherbourg
# 2   7.9250  26.0              Jyväskylä, Finland  Southampton
# 3  53.1000  35.0     Scituate, Massachusetts, US  Southampton
# 8  11.1333  26.0       St. Charles, Illinois, US  Southampton
# 9  30.0708  14.0  Zahlé, Lebanon, Ottoman Empire    Cherbourg
#
#                    Destination
# 1       New York, New York, US
# 2                New York City
# 3  Scituate, Massachusetts, US
# ...

# %%
dead_only = data_df.loc[data_df['Survived'] == 0.0]
dead_only.head()
# Out:
# PassengerId        549
# Survived           549
# Passenger Class    549
# Sex                549
# Siblings           549
# Parent/Child       549
# Fare               549
# Age                546
# Hometown           548
# Boarded            548
# Destination        548
# dtype: int64

# %%
survivor_only.to_csv(r'survivor.csv', index = False)
dead_only.to_csv(r'dead.csv', index = False)

# %%
# Read in data into a dataframe
test_data = pd.read_csv('data/train.csv')

# Display top of dataframe
test_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  WikiId  \
# 0      0         A/5 21171   7.2500   NaN        S   691.0
# 1      0          PC 17599  71.2833   C85        C    90.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S   865.0
# 3      0            113803  53.1000  C123        S   127.0
# ...

# %%
test_df = test_data.drop(['Age', 'Name', 'Name_wiki', 'Body', 'Lifeboat', 'Cabin', 'Ticket', 'Embarked', 'WikiId', 'Class'], axis='columns')

# %%
test_df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare  Age_wiki  \
# 0            1       0.0       3    male      1      0   7.2500      22.0
# 1            2       1.0       1  female      1      0  71.2833      35.0
# 2            3       1.0       3  female      0      0   7.9250      26.0
# 3            4       1.0       1  female      1      0  53.1000      35.0
# 4            5       0.0       3    male      0      0   8.0500      35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination
# 0  Qu'Appelle Valley, Saskatchewan, Canada
# 1                   New York, New York, US
# 2                            New York City
# ...

# %%
test_df = test_df.rename(columns={"Pclass":"Passenger Class", "SibSp":"Siblings", "Parch":"Parent/Child", "Age_wiki":"Age"})
test_df.head()
# Out:
#    PassengerId  Survived  Passenger Class     Sex  Siblings  Parent/Child  \
# 0            1       0.0                3    male         1             0
# 1            2       1.0                1  female         1             0
# 2            3       1.0                3  female         0             0
# 3            4       1.0                1  female         1             0
# 4            5       0.0                3    male         0             0
#
#       Fare   Age                            Hometown      Boarded  \
# 0   7.2500  22.0          Bridgerule, Devon, England  Southampton
# 1  71.2833  35.0              New York, New York, US    Cherbourg
# 2   7.9250  26.0                  Jyväskylä, Finland  Southampton
# 3  53.1000  35.0         Scituate, Massachusetts, US  Southampton
# 4   8.0500  35.0  Birmingham, West Midlands, England  Southampton
#
#                                Destination
# 0  Qu'Appelle Valley, Saskatchewan, Canada
# ...

# %%
test_df.to_csv(r'clean_train.csv', index = False)

# %%
train_data = pd.read_csv('data/clean_train.csv')

# %%
test = pd.read_csv('data/test.csv')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  WikiId  \
# 0  34.5      0      0   330911   7.8292   NaN        Q   928.0
# 1  47.0      1      0   363272   7.0000   NaN        S  1297.0
# 2  62.0      0      0   240276   9.6875   NaN        Q   518.0
# 3  27.0      0      0   315154   8.6625   NaN        S  1303.0
# 4  22.0      1      1  3101298  12.2875   NaN        S   871.0
#
#                                         Name_wiki  Age_wiki  \
# ...

# %%
test_data = test.drop(['Age', 'Name', 'Name_wiki', 'Body', 'Lifeboat', 'Cabin', 'Ticket', 'Embarked', 'WikiId', 'Class'], axis='columns')

# %%
test_data = test_data.rename(columns={"Pclass":"Passenger Class", "SibSp":"Siblings", "Parch":"Parent/Child", "Age_wiki":"Age"})
test_data.head()
# Out:
#    PassengerId  Passenger Class     Sex  Siblings  Parent/Child     Fare  \
# 0          892                3    male         0             0   7.8292
# 1          893                3  female         1             0   7.0000
# 2          894                2    male         0             0   9.6875
# 3          895                3    male         0             0   8.6625
# 4          896                3  female         1             1  12.2875
#
#     Age                     Hometown      Boarded                 Destination
# 0  19.0             Unknown, Ireland  Southampton               New York City
# 1  47.0  Penzance, Cornwall, England  Southampton             Akron, Ohio, US
# 2  63.0      Fermoy, Ireland[note 1]   Queenstown    Waban, Massachusetts, US
# 3  27.0           Uster, Switzerland  Southampton       Beloit, Wisconsin, US
# 4  22.0        Taalintehdas, Finland  Southampton  Monessen, Pennsylvania, US

# %%
test_data.to_csv(r'clean_test.csv', index = False)
